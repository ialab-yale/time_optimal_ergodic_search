# %%
import matplotlib.pyplot as plt

# %%
erg_ubs = [0.4457012232440685, 0.09430300324392804, 0.04284366620455568, 0.0090641994046851114, 0.0036160365096282454, 0.0006511325247227666, 0.00018496543763877704, 0.00006]
dists = [1.55, 6.22, 13.86, 16.30, 43.16, 50.0, 48.93, 47.23]
lawn = [4.5, 13.8, 23.4, 38.7, 92.25, 250.6449, 511.83, 1034.9312]

# %%
plt.yscale("log")
plt.xscale("log")
plt.xlabel("Ergodic Metric")
plt.ylabel("Path Distance")
plt.title("Minimum Distance Optimization vs. Lawnmower Trajectory")
plt.plot(erg_ubs, dists, "-o", label="min distance")
plt.plot(erg_ubs, lawn, "-o", label="lawnmower")
plt.legend()
