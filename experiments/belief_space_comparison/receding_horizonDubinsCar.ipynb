# %%
import sys 
sys.path.append('../..')

import jax
from functools import partial
from jax import grad, jacfwd, vmap, jit, hessian, value_and_grad
from jax.lax import scan
# from jax.ops import index_update, index
import jax.random as jnp_random
import jax.numpy as np

from jax.flatten_util import ravel_pytree

import numpy as onp
from time_opt_erg_lib.dynamics import DoubleIntegrator, KinematicUnicycle

from time_opt_erg_lib.ergodic_metric import ErgodicMetric
from time_opt_erg_lib.obstacle import Obstacle
from time_opt_erg_lib.cbf import constr2CBF
from time_opt_erg_lib.fourier_utils import BasisFunc, get_phik, get_ck, recon_from_fourier
# from time_opt_erg_lib.target_distribution import TargetDistribution
from time_opt_erg_lib.cbf_utils import sdf2cbf
from IPython.display import clear_output
import matplotlib.pyplot as plt

from time_opt_erg_lib.opt_solver import AugmentedLagrangeSolver
import yaml
import pickle as pkl

from bayes_filter import BayesFilter

# %%
class CkDynamics(object):
    def __init__(self, basis, _bnds) -> None:
        self._bnds = _bnds
        self.basis = basis
        self._ck_state = np.zeros(basis.k_list.shape[0])
        self._t_curr = 0.0
        self.domain = np.meshgrid(
            *[
                np.linspace(_bnds[0][0],_bnds[0][1]),
                np.linspace(_bnds[1][0],_bnds[1][1])
            ]
        )
        self.x_vals = np.stack([X.ravel() for X in self.domain]).T
    def recon_ck(self):
        return recon_from_fourier(self._ck_state/self._t_curr, self.basis, self.basis.k_list, self.x_vals)
    def plot_ck(self):
        evals = self.recon_ck()
        plt.contour(self.domain[0], self.domain[1], evals.reshape(self.domain[0].shape))
    def step(self, x, dt):
        self._ck_state = self._ck_state + dt * self.basis.fk_vmap(x)
        self._t_curr = self._t_curr + dt

# %%
class TimeOptErgodicPlanner(object):
    def __init__(self, target_distribution, args) -> None:
        _bnds = args['wrksp_bnds']
        def emap(x):
            """ Function that maps states to workspace """
            return np.array([
                (x[0]-_bnds[0][0])/(_bnds[0][1]-_bnds[0][0]), 
                (x[1]-_bnds[1][0])/(_bnds[1][1]-_bnds[1][0])])
        vmap_emap = vmap(emap)

        basis           = BasisFunc(n_basis=[8,8], emap=emap)
        self._ck_dynamics = CkDynamics(basis, _bnds)
        self.basis = basis 
        erg_metric      = ErgodicMetric(basis)
        robot_model     = KinematicUnicycle()
        n,m = robot_model.n, robot_model.m
        args.update({
            'phik' : get_phik(target_distribution.evals, basis),
            'ck_state' : self._ck_dynamics._ck_state
        })
        # @jit
        def loss(params, args):
            tf  = params['tf']
            """ Traj opt loss function, not the same as erg metric """
            return tf

        def eq_constr(params, args):
            """ dynamic equality constriants """
            x = params['x']
            u = params['u']
            x0 = args['x0']
            xf = args['xf']
            tf = params['tf']
            N = args['N']
            dt = tf/N
            return np.vstack([
                x[0] - x0, 
                x[1:,:]-(x[:-1,:]+dt*vmap(robot_model.dfdt)(x[:-1,:], u[:-1,:])),
                (x[-1] - xf)*0
            ])

        def ineq_constr(params, args):
            """ inequality constraints"""
            x = params['x']
            u = params['u']
            phik    = args['phik']
            tf      = params['tf']
            N       = args['N']
            dt      = tf/N
            e = vmap_emap(x)
            ck = (get_ck(x, basis, tf, dt) * tf + args['ck_state'])/(args['t_curr'] + tf)
            _erg_ineq = [np.array([erg_metric(ck, phik) - args['erg_ub'], -tf])]
            _ctrl_box = [(np.abs(u) - 1.).flatten()]
            _expl_box = [(-e).flatten(), (e-1.0).flatten()]
            return np.concatenate(_erg_ineq + _ctrl_box + _expl_box)


        x = np.linspace(args['x0'], args['xf'], args['N'], endpoint=True)
        u = np.zeros((args['N'], robot_model.m))
        init_sol = {'x': x, 'u' : u, 'tf': np.array(10.0)}
        self.solver = AugmentedLagrangeSolver(
                        init_sol,
                        loss, 
                        eq_constr, 
                        ineq_constr, 
                        args, 
                        step_size=1e-3,
                        c=10.0)
    def update_plan(self, args, max_iter=10_000):
        self.solver.solve(args, max_iter=max_iter)
        return self.solver.get_solution()

# %%
args = {
    'N' : 50, 
    'x0' : np.array([0., 0.1, 0.]),
    'xf' : np.array([.9, .9, 0.]),
    'erg_ub' : 0.1,
    'wrksp_bnds' : np.array([[-2.,2.],[-2.,2.]]), 
    't_curr' : 0, 
    'tf' : 10.0
}

def meas_model(p, x):
    # return np.linalg.norm(x-p + 1e-3)
    return jax.lax.atan2(p[0]-x[0], p[1]-x[1] + 1e-3)

target_distribution = BayesFilter(meas_model, lambda x: 1.0, args['wrksp_bnds'])
robot = KinematicUnicycle()
planner = TimeOptErgodicPlanner(target_distribution, args)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714590055.459916       1 tfrt_cpu_pjrt_client.cc:349] TfrtCpuClient created.

# %%
_distractor_p = np.array([0.,0.])
_true_p = np.array([1.75, -0.75])
_robot_state = np.array(args['x0'])
dt_list = []

for _ in range(100):
    planner.solver.reset()
    sol = planner.update_plan(args)
    _dt = sol['tf']/args['N']
    dt_list.append(_dt)
    _robot_state = _robot_state + _dt * robot.dfdt(_robot_state, sol['u'][0])
    planner._ck_dynamics.step(_robot_state, _dt)
    args.update({
        'x0': _robot_state,
        'ck_state' : planner._ck_dynamics._ck_state, 
        't_curr' : planner._ck_dynamics._t_curr
    })
    _y = meas_model(_robot_state[:2], _true_p) + onp.random.uniform(0., 0.1)
    # _y_distract = meas_model(_robot_state[:2], _distractor_p) + onp.random.uniform(0., 0.1)
    print(planner._ck_dynamics._t_curr % 2.0, planner._ck_dynamics._t_curr)
    target_distribution.update_prior(_robot_state[:2], _y)
    # target_distribution.update_prior(_robot_state[:2], _y_distract)
    target_distribution.update_eid()
    args.update({
        'phik' : get_phik(target_distribution.evals, planner.basis)
    })
    clear_output(wait=True)
    # target_distribution.plot_eid()
    target_distribution.plot_prior()
    # planner._ck_dynamics.plot_ck()
    plt.plot(sol['x'][:,0], sol['x'][:,1])
    plt.show()
# Out:
# unsuccessful, tol:  82968580.0
# 0.042342663 4.0423427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      21 target_distribution.update_prior(_robot_state[:2], _y)
#      22 # target_distribution.update_prior(_robot_state[:2], _y_distract)
# ---> 23 target_distribution.update_eid()
#      24 args.update({
#      25     'phik' : get_phik(target_distribution.evals, planner.basis)
#      26 })
#      27 clear_output(wait=True)
#
# File ~/PlayGround/time_optimal_ergodic_ros_env/src/time_optimal_ergodic_control/experiments/time_varying_search/bayes_filter.py:44, in BayesFilter.update_eid(self)
#      42 def update_eid(self):
#      43     fish_val = lambda x: np.trace(self.eid(x))
# ---> 44     self.evals = (vmap(fish_val)(self._s), self._s)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:1249, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1246 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1247 axis_size_ = (axis_size if axis_size is not None else
#    1248               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1249 out_flat = batching.batch(
#    1250     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1251     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1252     spmd_axis_name=spmd_axis_name
#    1253 ).call_wrapped(*args_flat)
#    1254 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/PlayGround/time_optimal_ergodic_ros_env/src/time_optimal_ergodic_control/experiments/time_varying_search/bayes_filter.py:43, in BayesFilter.update_eid.<locals>.<lambda>(x)
#      42 def update_eid(self):
# ---> 43     fish_val = lambda x: np.trace(self.eid(x))
#      44     self.evals = (vmap(fish_val)(self._s), self._s)
#
# File ~/PlayGround/time_optimal_ergodic_ros_env/src/time_optimal_ergodic_control/experiments/time_varying_search/bayes_filter.py:32, in BayesFilter.eid(self, x)
#      31 def eid(self, x):
# ---> 32     _instant_eid = vmap(self.score, in_axes=(0, None))(self._s, x)
#      33     return np.sum(vmap(np.dot)(_instant_eid, self._prior), axis=0)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:1249, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1246 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1247 axis_size_ = (axis_size if axis_size is not None else
#    1248               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1249 out_flat = batching.batch(
#    1250     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1251     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1252     spmd_axis_name=spmd_axis_name
#    1253 ).call_wrapped(*args_flat)
#    1254 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:851, in jacfwd.<locals>.jacfun(*args, **kwargs)
#     849 if not has_aux:
#     850   pushfwd: Callable = partial(_jvp, f_partial, dyn_args)
# --> 851   y, jac = vmap(pushfwd, out_axes=(None, -1))(_std_basis(dyn_args))
#     852 else:
#     853   pushfwd: Callable = partial(_jvp, f_partial, dyn_args, has_aux=True)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:1249, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1246 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1247 axis_size_ = (axis_size if axis_size is not None else
#    1248               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1249 out_flat = batching.batch(
#    1250     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1251     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1252     spmd_axis_name=spmd_axis_name
#    1253 ).call_wrapped(*args_flat)
#    1254 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:1989, in _jvp(fun, primals, tangents, has_aux)
#    1987 if not has_aux:
#    1988   flat_fun, out_tree = flatten_fun_nokwargs(fun, tree_def)
# -> 1989   out_primals, out_tangents = ad.jvp(flat_fun).call_wrapped(ps_flat, ts_flat)
#    1990   out_tree = out_tree()
#    1991   return (tree_unflatten(out_tree, out_primals),
#    1992           tree_unflatten(out_tree, out_tangents))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:938, in jacrev.<locals>.jacfun(*args, **kwargs)
#     936 tree_map(partial(_check_input_dtype_jacrev, holomorphic, allow_int), dyn_args)
#     937 if not has_aux:
# --> 938   y, pullback = _vjp(f_partial, *dyn_args)
#     939 else:
#     940   y, pullback, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/api.py:2238, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2236 if not has_aux:
#    2237   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2238   out_primal, out_vjp = ad.vjp(
#    2239       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2240   out_tree = out_tree()
#    2241 else:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:140, in vjp(traceable, primals, has_aux, reduce_axes)
#     138 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     139   if not has_aux:
# --> 140     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     141   else:
#     142     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:129, in linearize(traceable, *primals, **kwargs)
#     127 _, in_tree = tree_flatten(((primals, primals), {}))
#     128 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 129 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     130 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     131 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/profiler.py:340, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     337 @wraps(func)
#     338 def wrapper(*args, **kwargs):
#     339   with TraceAnnotation(name, **decorator_kwargs):
# --> 340     return func(*args, **kwargs)
#     341   return wrapper
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# Cell In[4], line 13, in meas_model(p, x)
#      11 def meas_model(p, x):
#      12     # return np.linalg.norm(x-p + 1e-3)
# ---> 13     return jax.lax.atan2(p[0]-x[0], p[1]-x[1] + 1e-3)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:338, in atan2(x, y)
#     335 def atan2(x: ArrayLike, y: ArrayLike) -> Array:
#     336   r"""Elementwise arc tangent of two variables:
#     337     :math:`\mathrm{atan}({x \over y})`."""
# --> 338   return atan2_p.bind(x, y)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:385, in Primitive.bind(self, *args, **params)
#     382 def bind(self, *args, **params):
#     383   assert (not config.enable_checks.value or
#     384           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 385   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:316, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     314   msg = f"Differentiation rule for '{primitive}' not implemented"
#     315   raise NotImplementedError(msg)
# --> 316 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     317 if primitive.multiple_results:
#     318   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:533, in standard_jvp(jvprules, primitive, primals, tangents, **params)
#     531 def standard_jvp(jvprules, primitive, primals, tangents, **params):
#     532   val_out = primitive.bind(*primals, **params)
# --> 533   tangents_out = [rule(t, *primals, **params) for rule, t in zip(jvprules, tangents)
#     534                   if rule is not None and type(t) is not Zero]
#     535   return val_out, functools.reduce(add_tangents, tangents_out, Zero.from_value(val_out))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:533, in <listcomp>(.0)
#     531 def standard_jvp(jvprules, primitive, primals, tangents, **params):
#     532   val_out = primitive.bind(*primals, **params)
# --> 533   tangents_out = [rule(t, *primals, **params) for rule, t in zip(jvprules, tangents)
#     534                   if rule is not None and type(t) is not Zero]
#     535   return val_out, functools.reduce(add_tangents, tangents_out, Zero.from_value(val_out))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:1866, in <lambda>(g, x, y)
#    1861 mlir.register_lowering(atan_p, partial(_nary_lower_hlo, chlo.AtanOp))
#    1863 atan2_p = standard_naryop([_float | _complex, _float | _complex], 'atan2')
#    1864 ad.defjvp(atan2_p,
#    1865           lambda g, x, y: g * (y / (square(x) + square(y))),
# -> 1866           lambda g, x, y: g * -x / (square(x) + square(y)))
#    1867 mlir.register_lowering(atan2_p, partial(_nary_lower_hlo, hlo.Atan2Op))
#    1869 sinh_p = standard_unop(_float | _complex, 'sinh')
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:1427, in square(x)
#    1425 def square(x: ArrayLike) -> Array:
#    1426   r"""Elementwise square: :math:`x^2`."""
# -> 1427   return integer_pow(x, 2)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:376, in integer_pow(x, y)
#     374 def integer_pow(x: ArrayLike, y: int) -> Array:
#     375   r"""Elementwise power: :math:`x^y`, where :math:`y` is a fixed integer."""
# --> 376   return integer_pow_p.bind(x, y=y)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:385, in Primitive.bind(self, *args, **params)
#     382 def bind(self, *args, **params):
#     383   assert (not config.enable_checks.value or
#     384           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 385   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:316, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     314   msg = f"Differentiation rule for '{primitive}' not implemented"
#     315   raise NotImplementedError(msg)
# --> 316 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     317 if primitive.multiple_results:
#     318   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:533, in standard_jvp(jvprules, primitive, primals, tangents, **params)
#     531 def standard_jvp(jvprules, primitive, primals, tangents, **params):
#     532   val_out = primitive.bind(*primals, **params)
# --> 533   tangents_out = [rule(t, *primals, **params) for rule, t in zip(jvprules, tangents)
#     534                   if rule is not None and type(t) is not Zero]
#     535   return val_out, functools.reduce(add_tangents, tangents_out, Zero.from_value(val_out))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:533, in <listcomp>(.0)
#     531 def standard_jvp(jvprules, primitive, primals, tangents, **params):
#     532   val_out = primitive.bind(*primals, **params)
# --> 533   tangents_out = [rule(t, *primals, **params) for rule, t in zip(jvprules, tangents)
#     534                   if rule is not None and type(t) is not Zero]
#     535   return val_out, functools.reduce(add_tangents, tangents_out, Zero.from_value(val_out))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:2032, in _integer_pow_jvp(g, x, y)
#    2031 def _integer_pow_jvp(g, x, *, y):
# -> 2032   return _zeros(g) if y == 0 else mul(g, mul(_const(x, y), integer_pow(x, y - 1)))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:424, in mul(x, y)
#     422 def mul(x: ArrayLike, y: ArrayLike) -> Array:
#     423   r"""Elementwise multiplication: :math:`x \times y`."""
# --> 424   return mul_p.bind(x, y)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:385, in Primitive.bind(self, *args, **params)
#     382 def bind(self, *args, **params):
#     383   assert (not config.enable_checks.value or
#     384           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 385   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:433, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     431   frame = self.get_frame(vals_in, dims_in)
#     432   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434 src = source_info_util.current()
#     435 if primitive.multiple_results:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:1000, in broadcast_batcher(prim, args, dims, **params)
#     995 shape, dim = next((x.shape, d) for x, d in zip(args, dims)
#     996                   if d is not not_mapped)
#     997 if all(core.definitely_equal_shape(shape, x.shape) and d == dim
#     998        for x, d in zip(args, dims) if np.ndim(x)):
#     999   # if there's only agreeing batch dims and scalars, just call the primitive
# -> 1000   out = prim.bind(*args, **params)
#    1001   return (out, (dim,) * len(out)) if prim.multiple_results else (out, dim)
#    1002 else:
#    1003   # We pass size of 1 here because (1) at least one argument has a real batch
#    1004   # dimension and (2) all unmapped axes can have a singleton axis inserted and
#    1005   # then rely on the primitive's built-in broadcasting.
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:385, in Primitive.bind(self, *args, **params)
#     382 def bind(self, *args, **params):
#     383   assert (not config.enable_checks.value or
#     384           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 385   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:433, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     431   frame = self.get_frame(vals_in, dims_in)
#     432   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434 src = source_info_util.current()
#     435 if primitive.multiple_results:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:1009, in broadcast_batcher(prim, args, dims, **params)
#    1006 args = [bdim_at_front(x, d, 1) if np.ndim(x) else x
#    1007         for x, d in zip(args, dims)]
#    1008 ndim = max(np.ndim(x) for x in args)  # special-case scalar broadcasting
# -> 1009 args = [_handle_scalar_broadcasting(ndim, x, d) for x, d in zip(args, dims)]
#    1010 out = prim.bind(*args, **params)
#    1011 return (out, (0,) * len(out)) if prim.multiple_results else (out, 0)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:1009, in <listcomp>(.0)
#    1006 args = [bdim_at_front(x, d, 1) if np.ndim(x) else x
#    1007         for x, d in zip(args, dims)]
#    1008 ndim = max(np.ndim(x) for x in args)  # special-case scalar broadcasting
# -> 1009 args = [_handle_scalar_broadcasting(ndim, x, d) for x, d in zip(args, dims)]
#    1010 out = prim.bind(*args, **params)
#    1011 return (out, (0,) * len(out)) if prim.multiple_results else (out, 0)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:1017, in _handle_scalar_broadcasting(nd, x, d)
#    1015   return x
#    1016 else:
# -> 1017   return jax.lax.expand_dims(x, tuple(range(np.ndim(x), nd)))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:1336, in expand_dims(array, dimensions)
#    1334   result_shape.insert(i, 1)
#    1335 broadcast_dims = [i for i in range(ndim_out) if i not in dims_set]
# -> 1336 return broadcast_in_dim(array, result_shape, broadcast_dims)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:803, in broadcast_in_dim(operand, shape, broadcast_dimensions)
#     801 else:
#     802   dyn_shape, static_shape = [], shape  # type: ignore
# --> 803 return broadcast_in_dim_p.bind(
#     804     operand, *dyn_shape, shape=tuple(static_shape),
#     805     broadcast_dimensions=tuple(broadcast_dimensions))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:385, in Primitive.bind(self, *args, **params)
#     382 def bind(self, *args, **params):
#     383   assert (not config.enable_checks.value or
#     384           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 385   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:433, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     431   frame = self.get_frame(vals_in, dims_in)
#     432   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434 src = source_info_util.current()
#     435 if primitive.multiple_results:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:2964, in _broadcast_in_dim_batch_rule(batched_args, batch_dims, shape, broadcast_dimensions)
#    2962   dyn_limits.append(bound)
#    2963 new_shape = (stacked_size,) + _merge_dyn_shape(shape, dyn_limits)
# -> 2964 result = broadcast_in_dim(new_operand, new_shape, new_broadcast_dimensions)
#    2965 out_ragged_axes = [idx+1 for idx, s in enumerate(shape) if s is None]
#    2966 out_bdim = batching.make_batch_axis(
#    2967     result.ndim, 0, zip(out_ragged_axes, out_ragged_sizes))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/lax.py:803, in broadcast_in_dim(operand, shape, broadcast_dimensions)
#     801 else:
#     802   dyn_shape, static_shape = [], shape  # type: ignore
# --> 803 return broadcast_in_dim_p.bind(
#     804     operand, *dyn_shape, shape=tuple(static_shape),
#     805     broadcast_dimensions=tuple(broadcast_dimensions))
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:385, in Primitive.bind(self, *args, **params)
#     382 def bind(self, *args, **params):
#     383   assert (not config.enable_checks.value or
#     384           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 385   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:868, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     867 def process_primitive(self, primitive, tracers, params):
# --> 868   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/dispatch.py:140, in apply_primitive(prim, *args, **params)
#     136   msg = pjit._device_assignment_mismatch_error(
#     137       prim.name, fails, args, 'jit', arg_names)
#     138   raise ValueError(msg) from None
# --> 140 return compiled_fun(*args)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/dispatch.py:172, in xla_primitive_callable.<locals>.<lambda>(*args, **kw)
#     170   call = compiled.unsafe_call
#     171 if not prim.multiple_results:
# --> 172   return lambda *args, **kw: call(*args, **kw)[0]
#     173 else:
#     174   return call
#
# KeyboardInterrupt:

# %%
plt.plot(dt_list)

# %%
planner._ck_dynamics._t_curr
# Out:
# Array(7.463266, dtype=float32, weak_type=True)

# %%
planner._ck_dynamics._t_curr
# Out:
# Array(24.294024, dtype=float32, weak_type=True)
